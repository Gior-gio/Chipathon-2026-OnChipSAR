# %% [markdown]
# # DAC Switch Testbench in Python
#
# This notebook implements a Python-based testbench for the design and verification of the DAC switch transmission gate used in the 10-bit SAR ADC developed for Chipathon 2026. It automates NGspice simulations while providing a convenient environment for data processing, visualization, and performance evaluation.
#
# The workflow assumes that the SPICE netlist has already been generated from Xschem. After the netlist is available, all simulation parameters are controlled directly from Python. The notebook is organized into independent sections covering **project configuration, simulation setup, waveform import and plotting, output spectrum analysis, and ENOB calculation**.

# %% [markdown]
# ## Project configuration:
#
# The following libraries are used throughout the notebook. They provide utilities for file management, SPICE netlist editing, simulation execution, data handling, and result visualization.

# %%
from pathlib import Path            # Manage file and directory paths
import subprocess                   # Execute external programs (NGspice)
import re                           # Search and replace netlist parameters
import warnings                     # Messages for the set_params function

import numpy as np                  # Numerical computations
import pandas as pd                 # Data import and manipulation
import matplotlib.pyplot as plt     # Plotting
from matplotlib.ticker import EngFormatter  # Engineering notation for axes

# %% [markdown]
# The paths shown below correspond to the **IIC Docker container version 2026.06**, where simulation files generated by Xschem are stored under `/headless/.xschem/simulations` and NGspice is installed in `/foss/tools/bin/ngspice`. If a different environment is used, these paths should be updated accordingly.

# %%
# Working directory containing the simulation files
WORK_DIR = Path("/headless/.xschem/simulations")

# NGspice executable
NGSPICE = "/foss/tools/bin/ngspice"

# Test-bench name
TB_NAME = "tb_dac_sw_1state"

# Default plotting style
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Nimbus Roman"],
    "font.size": 11,
})

# %% [markdown]
# Simulation parameters are defined in the SPICE netlist and updated automatically from Python, avoiding manual file edits. If a parameter is also redefined inside the `.control` block with a `let` statement, both definitions are updated to keep them consistent.

# %%
def set_params(netlist, **params):
    """
    Update multiple settings in a SPICE netlist in a single write operation.

    Supported settings:
      - .param definitions
      - let definitions inside .control
      - MOS process corner (.lib)
      - Resistor process corner (.lib)
      - MIM capacitor process corner (.lib)
      - Simulation temperature (.temp)

    Raises a warning if a setting is not found in the netlist.
    """

    VALID_CORNERS = {
        "typical",
        "ss",
        "sf",
        "fs",
        "ff",
        "statistical",
    }

    netlist = Path(netlist)
    text = netlist.read_text()

    for name, value in params.items():

        name = name.lower()

        # ------------------------------------------------------------
        # MOS process corner
        # ------------------------------------------------------------
        if name == "mos_corner":

            if value.lower() not in VALID_CORNERS:
                raise ValueError(
                    f"Invalid MOS corner '{value}'. "
                    f"Valid options are: {', '.join(sorted(VALID_CORNERS))}."
                )

            text, n = re.subn(
                r"(^\s*\.lib\s+\S+\s+)(typical|ss|sf|fs|ff|statistical)\s*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n == 0:
                warnings.warn(
                    "MOS corner not updated: no matching .lib statement found.",
                    RuntimeWarning,
                )

        # ------------------------------------------------------------
        # Resistor process corner
        # ------------------------------------------------------------
        elif name == "res_corner":

            if value.lower() not in VALID_CORNERS:
                raise ValueError(
                    f"Invalid resistor corner '{value}'. "
                    f"Valid options are: {', '.join(sorted(VALID_CORNERS))}."
                )

            text, n = re.subn(
                r"(^\s*\.lib\s+\S+\s+)res_(typical|ss|sf|fs|ff|statistical)\s*$",
                rf"\g<1>res_{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n == 0:
                warnings.warn(
                    "Resistor corner not updated: no matching .lib statement found.",
                    RuntimeWarning,
                )

        # ------------------------------------------------------------
        # MIM capacitor process corner
        # ------------------------------------------------------------
        elif name == "cap_corner":

            if value.lower() not in VALID_CORNERS:
                raise ValueError(
                    f"Invalid capacitor corner '{value}'. "
                    f"Valid options are: {', '.join(sorted(VALID_CORNERS))}."
                )

            # Verify that the base MIM capacitor library is present
            if not re.search(
                r"^\s*\.lib\s+\S+\s+cap_mim\s*$",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            ):
                warnings.warn(
                    "MIM capacitor base library ('cap_mim') not found.",
                    RuntimeWarning,
                )

            # Update the MIM capacitor corner
            text, n = re.subn(
                r"(^\s*\.lib\s+\S+\s+)mimcap_(typical|ss|sf|fs|ff|statistical)\s*$",
                rf"\g<1>mimcap_{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n == 0:
                warnings.warn(
                    "Capacitor corner not updated: no matching mimcap library found.",
                    RuntimeWarning,
                )

        # ------------------------------------------------------------
        # Simulation temperature
        # ------------------------------------------------------------
        elif name == "temp":

            text, n = re.subn(
                r"(^\s*\.temp\s+).*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n == 0:
                warnings.warn(
                    "Temperature not updated: no .temp statement found.",
                    RuntimeWarning,
                )

        # ------------------------------------------------------------
        # .param and let definitions
        # ------------------------------------------------------------
        else:

            text, n1 = re.subn(
                rf"(^\s*\.param\s+{re.escape(name)}\s*=\s*).*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            text, n2 = re.subn(
                rf"(^\s*let\s+{re.escape(name)}\s*=\s*).*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n1 + n2 == 0:
                warnings.warn(
                    f"Parameter '{name}' not found in .param or let definitions.",
                    RuntimeWarning,
                )

    netlist.write_text(text)

# %% [markdown]
# ## **Simulation setup and run**

# %%
# Sampling parameters
Fs = 5e6
Ns = 1024
Nc = 103

# Testbench parameters
MOS_CORNER = "ss"
VDD = 3.3*0.9
TEMP = -40
Cload = "0.2p"
Nspare = 5

# %% [markdown]
# The simulation is launched from the working directory so that all output files, such as exported waveforms, are generated in the work directory. Finally, the NGspice console output is printed to facilitate debugging and verify that the simulation completed successfully.

# %%
# SPICE netlist
NETLIST = WORK_DIR / f"{TB_NAME}.spice"

# Simulation parameters
SIM_CONFIG = {
    "mos_corner": MOS_CORNER,
    "temp": TEMP,
    "VDD": VDD,
    "Fs": f"{Fs:g}",
    "Ns": Ns,
    "Nc": Nc,
    "Cload": Cload,
    "Nspare": Nspare,
}

set_params(NETLIST, **SIM_CONFIG)

# Run NGspice in batch mode
result = subprocess.run(
    [NGSPICE, "-b", str(NETLIST)],
    cwd=WORK_DIR,
    capture_output=True,
    text=True,
)

# Display the NGspice output
print(result.stdout)

# Print the error log if the simulation failed
if result.returncode != 0:
    print(result.stderr)
# Out:
# Note: Compatibility modes selected: hs a
#
#
# Circuit: ** sch_path: /foss/designs/chipathon-2026-onchipsar/designs/sar_adc/dac/dac_sw_1state/xschem/tb_dac_sw_1state.sch
#
# Doing analysis at TEMP = -40.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#
# Initial Transient Solution
# --------------------------
#
# Node                                   Voltage
# ----                                   -------
# vdd                                       2.97
# vss                                          0
# vin                                      1.485
# clk                                          0
# vout                                   1.48511
# clkn                                      2.97
# vclk#branch                                  0
# vsin#branch                        4.44089e-16
# vsn#branch                         8.91025e-12
# vsp#branch                        -8.91052e-12
#
#  Reference value :  1.91609e-07
#  Reference value :  6.00080e-07
#  Reference value :  8.00780e-07
#  Reference value :  1.31722e-06
#  Reference value :  1.50202e-06
#  Reference value :  1.98282e-06
#  Reference value :  2.46195e-06
#  Reference value :  2.78915e-06
#  Reference value :  3.00129e-06
#  Reference value :  3.51082e-06
#  Reference value :  4.00056e-06
#  Reference value :  4.41423e-06
#  Reference value :  4.81823e-06
#  Reference value :  5.16442e-06
#  Reference value :  5.56762e-06
#  Reference value :  5.94202e-06
#  Reference value :  6.40008e-06
#  Reference value :  6.71795e-06
#  Reference value :  7.21084e-06
#  Reference value :  7.87482e-06
#  Reference value :  8.61180e-06
#  Reference value :  9.55402e-06
#  Reference value :  1.04189e-05
#  Reference value :  1.12042e-05
#  Reference value :  1.15428e-05
#  Reference value :  1.18013e-05
#  Reference value :  1.19036e-05
#  Reference value :  1.21092e-05
#  Reference value :  1.23252e-05
#  Reference value :  1.26324e-05
#  Reference value :  1.30892e-05
#  Reference value :  1.32900e-05
#  Reference value :  1.33884e-05
#  Reference value :  1.34137e-05
#  Reference value :  1.35236e-05
#  Reference value :  1.37860e-05
#  Reference value :  1.41676e-05
#  Reference value :  1.47444e-05
#  Reference value :  1.51724e-05
#  Reference value :  1.56980e-05
#  Reference value :  1.64134e-05
#  Reference value :  1.70676e-05
#  Reference value :  1.78828e-05
#  Reference value :  1.87116e-05
#  Reference value :  1.93716e-05
#  Reference value :  2.01108e-05
#  Reference value :  2.08692e-05
#  Reference value :  2.17252e-05
#  Reference value :  2.23900e-05
#  Reference value :  2.32172e-05
#  Reference value :  2.40420e-05
#  Reference value :  2.49156e-05
#  Reference value :  2.55548e-05
#  Reference value :  2.64038e-05
#  Reference value :  2.72252e-05
#  Reference value :  2.80804e-05
#  Reference value :  2.85563e-05
#  Reference value :  2.93956e-05
#  Reference value :  3.01908e-05
#  Reference value :  3.10268e-05
#  Reference value :  3.16156e-05
#  Reference value :  3.20780e-05
#  Reference value :  3.27492e-05
#  Reference value :  3.36191e-05
#  Reference value :  3.43779e-05
#  Reference value :  3.51908e-05
#  Reference value :  3.61588e-05
#  Reference value :  3.70316e-05
#  Reference value :  3.76732e-05
#  Reference value :  3.83715e-05
#  Reference value :  3.90732e-05
#  Reference value :  3.98008e-05
#  Reference value :  4.05460e-05
#  Reference value :  4.13644e-05
#  Reference value :  4.22219e-05
#  Reference value :  4.29820e-05
#  Reference value :  4.37396e-05
#  Reference value :  4.45756e-05
#  Reference value :  4.54284e-05
#  Reference value :  4.63171e-05
#  Reference value :  4.72145e-05
#  Reference value :  4.78008e-05
#  Reference value :  4.85388e-05
#  Reference value :  4.93940e-05
#  Reference value :  5.01780e-05
#  Reference value :  5.08111e-05
#  Reference value :  5.14852e-05
#  Reference value :  5.22883e-05
#  Reference value :  5.30136e-05
#  Reference value :  5.39076e-05
#  Reference value :  5.48063e-05
#  Reference value :  5.55994e-05
#  Reference value :  5.63811e-05
#  Reference value :  5.68016e-05
#  Reference value :  5.72212e-05
#  Reference value :  5.76396e-05
#  Reference value :  5.82787e-05
#  Reference value :  5.90001e-05
#  Reference value :  5.94620e-05
#  Reference value :  5.98868e-05
#  Reference value :  6.05156e-05
#  Reference value :  6.12596e-05
#  Reference value :  6.20603e-05
#  Reference value :  6.29852e-05
#  Reference value :  6.38412e-05
#  Reference value :  6.46684e-05
#  Reference value :  6.54284e-05
#  Reference value :  6.62000e-05
#  Reference value :  6.69428e-05
#  Reference value :  6.74892e-05
#  Reference value :  6.81907e-05
#  Reference value :  6.88460e-05
#  Reference value :  6.95556e-05
#  Reference value :  7.00987e-05
#  Reference value :  7.05092e-05
#  Reference value :  7.09884e-05
#  Reference value :  7.14069e-05
#  Reference value :  7.19756e-05
#  Reference value :  7.27644e-05
#  Reference value :  7.35380e-05
#  Reference value :  7.43444e-05
#  Reference value :  7.52159e-05
#  Reference value :  7.60010e-05
#  Reference value :  7.69532e-05
#  Reference value :  7.78396e-05
#  Reference value :  7.86660e-05
#  Reference value :  7.95324e-05
#  Reference value :  8.01659e-05
#  Reference value :  8.08652e-05
#  Reference value :  8.14143e-05
#  Reference value :  8.18182e-05
#  Reference value :  8.24580e-05
#  Reference value :  8.33540e-05
#  Reference value :  8.38364e-05
#  Reference value :  8.46348e-05
#  Reference value :  8.55700e-05
#  Reference value :  8.64668e-05
#  Reference value :  8.70932e-05
#  Reference value :  8.76844e-05
#  Reference value :  8.84172e-05
#  Reference value :  8.91012e-05
#  Reference value :  8.96372e-05
#  Reference value :  9.02548e-05
#  Reference value :  9.09916e-05
#  Reference value :  9.18356e-05
#  Reference value :  9.26588e-05
#  Reference value :  9.34764e-05
#  Reference value :  9.44236e-05
#  Reference value :  9.51748e-05
#  Reference value :  9.57284e-05
#  Reference value :  9.63940e-05
#  Reference value :  9.71044e-05
#  Reference value :  9.78379e-05
#  Reference value :  9.86356e-05
#  Reference value :  9.93100e-05
#  Reference value :  1.00017e-04
#  Reference value :  1.00764e-04
#  Reference value :  1.01564e-04
#  Reference value :  1.02217e-04
#  Reference value :  1.02784e-04
#  Reference value :  1.03280e-04
#  Reference value :  1.03664e-04
#  Reference value :  1.03924e-04
#  Reference value :  1.04264e-04
#  Reference value :  1.04467e-04
#  Reference value :  1.04818e-04
#  Reference value :  1.05300e-04
#  Reference value :  1.05984e-04
#  Reference value :  1.06576e-04
#  Reference value :  1.07088e-04
#  Reference value :  1.07614e-04
#  Reference value :  1.08067e-04
#  Reference value :  1.08205e-04
#  Reference value :  1.08630e-04
#  Reference value :  1.09276e-04
#  Reference value :  1.10146e-04
#  Reference value :  1.10947e-04
#  Reference value :  1.11788e-04
#  Reference value :  1.12601e-04
#  Reference value :  1.13485e-04
#  Reference value :  1.14160e-04
#  Reference value :  1.14995e-04
#  Reference value :  1.15519e-04
#  Reference value :  1.16042e-04
#  Reference value :  1.16778e-04
#  Reference value :  1.17637e-04
#  Reference value :  1.18413e-04
#  Reference value :  1.19199e-04
#  Reference value :  1.19824e-04
#  Reference value :  1.20185e-04
#  Reference value :  1.20601e-04
#  Reference value :  1.20752e-04
#  Reference value :  1.21179e-04
#  Reference value :  1.21737e-04
#  Reference value :  1.22487e-04
#  Reference value :  1.23230e-04
#  Reference value :  1.23941e-04
#  Reference value :  1.24468e-04
#  Reference value :  1.25023e-04
#  Reference value :  1.25564e-04
#  Reference value :  1.26322e-04
#  Reference value :  1.27201e-04
#  Reference value :  1.28019e-04
#  Reference value :  1.28759e-04
#  Reference value :  1.29506e-04
#  Reference value :  1.30331e-04
#  Reference value :  1.31241e-04
#  Reference value :  1.31984e-04
#  Reference value :  1.32780e-04
#  Reference value :  1.33439e-04
#  Reference value :  1.34284e-04
#  Reference value :  1.35126e-04
#  Reference value :  1.35986e-04
#  Reference value :  1.36880e-04
#  Reference value :  1.37667e-04
#  Reference value :  1.38466e-04
#  Reference value :  1.39415e-04
#  Reference value :  1.40256e-04
#  Reference value :  1.41094e-04
#  Reference value :  1.41780e-04
#  Reference value :  1.42346e-04
#  Reference value :  1.43149e-04
#  Reference value :  1.44103e-04
#  Reference value :  1.44896e-04
#  Reference value :  1.45598e-04
#  Reference value :  1.46396e-04
#  Reference value :  1.47162e-04
#  Reference value :  1.47900e-04
#  Reference value :  1.48428e-04
#  Reference value :  1.49092e-04
#  Reference value :  1.49710e-04
#  Reference value :  1.50340e-04
#  Reference value :  1.51020e-04
#  Reference value :  1.51717e-04
#  Reference value :  1.52251e-04
#  Reference value :  1.52600e-04
#  Reference value :  1.52896e-04
#  Reference value :  1.53517e-04
#  Reference value :  1.54240e-04
#  Reference value :  1.54871e-04
#  Reference value :  1.55600e-04
#  Reference value :  1.56398e-04
#  Reference value :  1.57088e-04
#  Reference value :  1.57801e-04
#  Reference value :  1.58491e-04
#  Reference value :  1.59087e-04
#  Reference value :  1.59692e-04
#  Reference value :  1.60372e-04
#  Reference value :  1.61187e-04
#  Reference value :  1.61938e-04
#  Reference value :  1.62629e-04
#  Reference value :  1.63183e-04
#  Reference value :  1.63611e-04
#  Reference value :  1.63936e-04
#  Reference value :  1.64480e-04
#  Reference value :  1.65018e-04
#  Reference value :  1.65264e-04
#  Reference value :  1.65286e-04
#  Reference value :  1.65441e-04
#  Reference value :  1.66080e-04
#  Reference value :  1.66610e-04
#  Reference value :  1.67066e-04
#  Reference value :  1.67540e-04
#  Reference value :  1.68036e-04
#  Reference value :  1.68491e-04
#  Reference value :  1.68929e-04
#  Reference value :  1.69457e-04
#  Reference value :  1.70305e-04
#  Reference value :  1.71272e-04
#  Reference value :  1.72013e-04
#  Reference value :  1.72572e-04
#  Reference value :  1.72824e-04
#  Reference value :  1.73019e-04
#  Reference value :  1.73597e-04
#  Reference value :  1.74010e-04
#  Reference value :  1.74615e-04
#  Reference value :  1.75285e-04
#  Reference value :  1.75745e-04
#  Reference value :  1.76081e-04
#  Reference value :  1.76444e-04
#  Reference value :  1.77011e-04
#  Reference value :  1.77748e-04
#  Reference value :  1.78085e-04
#  Reference value :  1.78753e-04
#  Reference value :  1.79740e-04
#  Reference value :  1.80543e-04
#  Reference value :  1.81220e-04
#  Reference value :  1.81776e-04
#  Reference value :  1.82272e-04
#  Reference value :  1.82470e-04
#  Reference value :  1.82888e-04
#  Reference value :  1.83593e-04
#  Reference value :  1.84064e-04
#  Reference value :  1.84772e-04
#  Reference value :  1.85504e-04
#  Reference value :  1.86316e-04
#  Reference value :  1.87216e-04
#  Reference value :  1.87835e-04
#  Reference value :  1.88349e-04
#  Reference value :  1.89018e-04
#  Reference value :  1.89844e-04
#  Reference value :  1.90657e-04
#  Reference value :  1.91602e-04
#  Reference value :  1.92537e-04
#  Reference value :  1.93552e-04
#  Reference value :  1.94526e-04
#  Reference value :  1.95309e-04
#  Reference value :  1.96126e-04
#  Reference value :  1.97065e-04
#  Reference value :  1.97882e-04
#  Reference value :  1.98694e-04
#  Reference value :  1.99517e-04
#  Reference value :  2.00227e-04
#  Reference value :  2.01059e-04
#  Reference value :  2.01903e-04
#  Reference value :  2.02824e-04
#  Reference value :  2.03922e-04
#  Reference value :  2.04880e-04
#  Reference value :  2.05792e-04
# No. of Data Rows : 271883
# p_avg               =  2.29339e-07 from=  0.00000e+00 to=  2.05800e-04
# p_avg = 2.293395e-07
# Note: Simulation executed from .control section

# %% [markdown]
# ## Waveform import
#
# The transient data exported by NGspice is imported into a Pandas DataFrame with descriptive column names. Since `wrdata` generates one time column per waveform, duplicated time vectors are verified for consistency and merged into a single `time` column for subsequent analysis.

# %%
data = pd.read_csv(
    WORK_DIR / f"{TB_NAME}.csv",
    sep=r"\s+",
    header=None,
    names=[
        "time", "vin",
        "t_vout", "vout",
        "t_clk", "clk",
        "t_pdd", "pdd",
    ]
)

# Verify that all time columns are equivalent
if not (
    np.allclose(data["time"], data["t_vout"]) and
    np.allclose(data["time"], data["t_clk"]) and
    np.allclose(data["time"], data["t_pdd"])
):
    raise ValueError("Time columns are not identical.")

# Keep a single time column
data = data[["time", "vin", "vout", "clk", "pdd"]]

print(data.head())
# Out:
#            time       vin      vout    clk           pdd
# 0  0.000000e+00  1.485000  1.485115  0.000  2.646423e-11
# 1  8.000000e-10  1.488754  1.484150  2.376 -2.554051e-05
# 2  1.600000e-09  1.492508  1.488968  2.970 -3.414937e-07
# 3  2.400000e-09  1.496262  1.492613  2.970  2.026742e-08
# 4  3.200000e-09  1.500016  1.496304  2.970 -6.620711e-08

# %% [markdown]
# ## Plot Waveforms
#
# To simplify visualization, only the first input signal period is displayed. The period is computed automatically from the simulation parameters, and the resulting plots show the input voltage, sampled output voltage, and sampling clock on a common time axis.

# %%
# Compute the input frequency and period
Fin = Nc / Ns * Fs
Tin = 1 / Fin

# Keep only the first input period
data_plot = data[data["time"] <= Tin]

# Create the figure
fig, (ax1, ax2) = plt.subplots(
    2, 1,
    figsize=(4, 3.5),
    sharex=True,
    constrained_layout=True,
)

# Plot the input and output voltages
ax1.plot(data_plot["time"], data_plot["vin"], label=r"$V_{in}$", color="tab:blue")
ax1.plot(data_plot["time"], data_plot["vout"], label=r"$V_{out}$", color="tab:red")

ax1.set_ylabel("Voltage (V)")
ax1.grid(True, linestyle=":", linewidth=0.6)
ax1.legend(loc="upper right")

# Plot the sampling clock
ax2.plot(data_plot["time"], data_plot["clk"], label="Samp CLK", color="goldenrod")

ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Voltage (V)")
ax2.grid(True, linestyle=":", linewidth=0.6)
ax2.legend(loc="upper right")

# Display the time axis using engineering notation
ax2.xaxis.set_major_formatter(EngFormatter(unit="s"))

plt.show()

# %% [markdown]
# ## Output FFT
#
# The output waveform is sampled at the same instants as the switched-capacitor circuit, starting after the initial discarded cycles to avoid switching transients. The sampled sequence is then processed using a normalized FFT to obtain the one-sided power spectrum for performance analysis.

# %%
# Sampling parameters
Ts = 1 / Fs
Ton = Ts / 12

# First sampling instant after the discarded cycles
t0 = Nspare * Ts + 2 * Ton

# Generate the sampling instants
sample_times = t0 + np.arange(Ns) * Ts

# Interpolate the transient waveform at the sampling instants
vout_samples = np.interp(
    sample_times,
    data["time"],
    data["vout"],
)

# Compute the normalized FFT
fft = np.fft.fft(vout_samples, n=Ns)
fft /= Ns

# Keep the one-sided spectrum
fft = fft[: Ns // 2 + 1]
fft[1:-1] *= 2

# Frequency axis
f = np.fft.rfftfreq(Ns, d=Ts)

# Power spectrum
PSD = np.abs(fft) ** 2

# Power spectrum in dB
PSD_db = 10 * np.log10(np.maximum(PSD, 1e-20))

# %% [markdown]
# The one-sided FFT computed in the previous section is displayed as a function of frequency. This spectrum provides a convenient representation of the sampled output and serves as the basis for evaluating the S&H performance.

# %%
# Create the figure
fig, ax = plt.subplots(figsize=(5, 3.2))

# Plot the one-sided spectrum
ax.plot(
    f[1:],
    PSD_db[1:],
    color="tab:blue",
    linewidth=1,
)

# Use engineering notation for the frequency axis
ax.xaxis.set_major_formatter(EngFormatter(unit="Hz"))

ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Magnitude (dB)")

# Configure the grid
ax.grid(
    True,
    which="both",
    linestyle=":",
    linewidth=0.6,
)

plt.show()

# %% [markdown]
# ## Compute metrics
#
# The one-sided power spectrum is used to evaluate the dynamic performance of the sampled signal. The following function computes the SNDR, SFDR, and ENOB over either the full Nyquist band or a user-defined bandwidth by separating the fundamental tone, the DC component, and the remaining spectral content.

# %%
def compute_metrics(PSD, f, fin, fs, Nfft, bandwidth=None):
    """
    Compute SNDR, SFDR, and ENOB over the selected frequency region.

    If bandwidth is None, the full spectrum is used.
    Otherwise, only frequencies below the specified bandwidth
    are included in the calculation.
    """

    df = fs / Nfft

    # Select the frequency region
    if bandwidth is None:
        region_mask = np.ones_like(f, dtype=bool)
    else:
        region_mask = np.abs(f) < bandwidth

    # Identify the fundamental tone and DC component
    fundamental_mask = np.abs(f - fin) < df / 2
    dc_mask = (f == 0)

    fundamental_mask &= region_mask
    dc_mask &= region_mask

    # Compute the signal, noise, and distortion powers
    total_power = np.sum(PSD[region_mask])
    fundamental_power = np.sum(PSD[fundamental_mask])
    dc_power = np.sum(PSD[dc_mask])

    noise_dist_power = total_power - fundamental_power - dc_power

    # Compute SNDR and ENOB
    sndr = 10 * np.log10(fundamental_power / noise_dist_power)
    enob = (sndr - 1.7609) / 6.0206

    # Compute SFDR
    spur_mask = region_mask & ~fundamental_mask & ~dc_mask

    if np.any(spur_mask):
        largest_spur_power = np.max(PSD[spur_mask])
        sfdr = 10 * np.log10(fundamental_power / largest_spur_power)
    else:
        sfdr = np.inf

    return sndr, sfdr, enob

# %% [markdown]
# Finally the metrics are obtained:

# %%
# Compute SNDR, SFDR, and ENOB over the full Nyquist band
sndr_full, sfdr_full, enob_full = compute_metrics(
    PSD,
    f,
    Fin,
    Fs,
    Ns,
)

# Compute the average supply power after the discarded samples
t0 = Nspare / Fs
pdd_avg = data.loc[data["time"] >= t0, "pdd"].mean()

# Display the results
print("============== RESULTS ==============")
print(f"SNDR : {sndr_full:.4f} dB")
print(f"SFDR : {sfdr_full:.4f} dB")
print(f"ENOB : {enob_full:.4f} bits")
print(f"PAVG : {1e6*pdd_avg:.2f} µW")
# Out:
# ============== RESULTS ==============
# SNDR : 56.2402 dB
# SFDR : 59.3034 dB
# ENOB : 9.0488 bits
# PAVG : 0.13 µW
