# %% [markdown]
# # Bootstrap Testbench in Python
#
# This notebook implements a Python-based testbench for the design and verification of the bootstrap Sample-and-Hold circuit used in the 10-bit SAR ADC developed for Chipathon 2026. It automates NGspice simulations while providing a convenient environment for data processing, visualization, and performance evaluation.
#
# The workflow assumes that the SPICE netlist has already been generated from Xschem. After the netlist is available, all simulation parameters are controlled directly from Python. The notebook is organized into independent sections covering **project configuration, simulation setup, waveform import and plotting, output spectrum analysis, and ENOB calculation**.

# %% [markdown]
# ## Project configuration:
#
# The following libraries are used throughout the notebook. They provide utilities for file management, SPICE netlist editing, simulation execution, data handling, and result visualization.

# %%
from pathlib import Path            # Manage file and directory paths
import subprocess                   # Execute external programs (NGspice)
import re                           # Search and replace netlist parameters
import warnings                     # Messages for the set_params function

import numpy as np                  # Numerical computations
import pandas as pd                 # Data import and manipulation
import matplotlib.pyplot as plt     # Plotting
from matplotlib.ticker import EngFormatter  # Engineering notation for axes

# %% [markdown]
# The paths shown below correspond to the **IIC Docker container version 2026.06**, where simulation files generated by Xschem are stored under `/headless/.xschem/simulations` and NGspice is installed in `/foss/tools/bin/ngspice`. If a different environment is used, these paths should be updated accordingly.

# %%
# Working directory containing the simulation files
WORK_DIR = Path("/headless/.xschem/simulations")

# NGspice executable
NGSPICE = "/foss/tools/bin/ngspice"

# Default plotting style
plt.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Nimbus Roman"],
    "font.size": 11,
})

# %% [markdown]
# Simulation parameters are defined in the SPICE netlist and updated automatically from Python, avoiding manual file edits. If a parameter is also redefined inside the `.control` block with a `let` statement, both definitions are updated to keep them consistent.

# %%
def set_params(netlist, **params):
    """
    Update multiple settings in a SPICE netlist in a single write operation.

    Raises a warning if a parameter is not found in the netlist
    (to avoid silent failures).
    """

    netlist = Path(netlist)
    text = netlist.read_text()

    for name, value in params.items():

        # -------------------------
        # Process corner
        # -------------------------
        if name.lower() == "corner":

            valid_corners = {
                "typical",
                "ss",
                "sf",
                "fs",
                "ff",
                "statistical",
            }

            if str(value).lower() not in valid_corners:
                raise ValueError(
                    f"Invalid corner '{value}'. "
                    f"Valid options are: {', '.join(sorted(valid_corners))}."
                )

            text, n = re.subn(
                r"(^\s*\.lib\s+\S+\s+)\S+\s*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n == 0:
                warnings.warn(
                    f"[set_params] Corner not updated: no .lib line found in netlist.",
                    RuntimeWarning,
                )

        # -------------------------
        # Temperature
        # -------------------------
        elif name.lower() == "temp":

            text, n = re.subn(
                r"(^\s*\.temp\s+).*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            if n == 0:
                warnings.warn(
                    f"[set_params] Temperature not updated: no .temp line found.",
                    RuntimeWarning,
                )

        # -------------------------
        # Params and control variables
        # -------------------------
        else:

            text_param, n1 = re.subn(
                rf"(^\s*\.param\s+{re.escape(name)}\s*=\s*).*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            text_let, n2 = re.subn(
                rf"(^\s*let\s+{re.escape(name)}\s*=\s*).*$",
                rf"\g<1>{value}",
                text,
                flags=re.MULTILINE | re.IGNORECASE,
            )

            text = text_param if n1 > 0 else text_let

            if n1 + n2 == 0:
                warnings.warn(
                    f"[set_params] Parameter '{name}' not found in .param or let definitions.",
                    RuntimeWarning,
                )

    netlist.write_text(text)

# %% [markdown]
# ## **Simulation setup and run**

# %%
# Sampling parameters
Fs = 5e6
Ns = 1024
Nc = 509

# Testbench parameters
PROCESS = "typical"
VDD = 3.3
TEMP = 27
Cload = "1p"
Nspare = 5

# %% [markdown]
# The simulation is launched from the working directory so that all output files, such as exported waveforms, are generated in the work directory. Finally, the NGspice console output is printed to facilitate debugging and verify that the simulation completed successfully.

# %%
# SPICE netlist
NETLIST = WORK_DIR / "tb_bootstrapped.spice"

# Simulation parameters
SIM_CONFIG = {
    "corner": PROCESS,
    "temp": TEMP,
    "VDD": VDD,
    "Fs": f"{Fs:g}",
    "Ns": Ns,
    "Nc": Nc,
    "Cload": Cload,
    "Nspare": Nspare,
}

set_params(NETLIST, **SIM_CONFIG)

# Run NGspice in batch mode
result = subprocess.run(
    [NGSPICE, "-b", str(NETLIST)],
    cwd=WORK_DIR,
    capture_output=True,
    text=True,
)

# Display the NGspice output
print(result.stdout)

# Print the error log if the simulation failed
if result.returncode != 0:
    print(result.stderr)
# Out:
# Note: Compatibility modes selected: hs a
#
#
# Circuit: ** sch_path: /foss/designs/chipathon-2026-onchipsar/designs/sar_adc/samplehold/bootstrapped/xschem/tb_bootstrapped.sch
#
# Doing analysis at TEMP = 27.000000 and TNOM = 27.000000
#
# Using SPARSE 1.3 as Direct Linear Solver
#
# Initial Transient Solution
# --------------------------
#
# Node                                   Voltage
# ----                                   -------
# vdd                                        3.3
# vss                                          0
# vin                                       1.65
# clk                                          0
# vout                                 0.0874613
# x2.net1                            1.08956e-09
# x2.clkn                                    3.3
# x2.cc                                      3.3
# x2.vx                              2.17912e-09
# x2.vcc                             3.69521e-09
# x2.vc                                      3.3
# v4#branch                                    0
# v3#branch                         -4.44444e-12
# v2#branch                            2.734e-11
# v1#branch                         -2.28955e-11
#
#  Reference value :  1.04474e-09
#  Reference value :  5.28806e-08
#  Reference value :  2.12432e-07
#  Reference value :  3.97079e-07
#  Reference value :  6.04972e-07
#  Reference value :  9.40386e-07
#  Reference value :  1.41767e-06
#  Reference value :  2.00687e-06
#  Reference value :  2.61078e-06
#  Reference value :  3.14706e-06
#  Reference value :  3.72790e-06
#  Reference value :  4.26456e-06
#  Reference value :  4.69372e-06
#  Reference value :  5.18872e-06
#  Reference value :  5.58955e-06
#  Reference value :  5.69291e-06
#  Reference value :  6.08291e-06
#  Reference value :  6.54041e-06
#  Reference value :  7.10288e-06
#  Reference value :  7.69208e-06
#  Reference value :  8.29454e-06
#  Reference value :  8.91376e-06
#  Reference value :  9.43537e-06
#  Reference value :  9.84204e-06
#  Reference value :  1.01910e-05
#  Reference value :  1.07154e-05
#  Reference value :  1.12190e-05
#  Reference value :  1.17976e-05
#  Reference value :  1.23270e-05
#  Reference value :  1.28277e-05
#  Reference value :  1.33518e-05
#  Reference value :  1.36501e-05
#  Reference value :  1.40551e-05
#  Reference value :  1.43062e-05
#  Reference value :  1.47712e-05
#  Reference value :  1.52526e-05
#  Reference value :  1.57526e-05
#  Reference value :  1.62870e-05
#  Reference value :  1.68194e-05
#  Reference value :  1.72776e-05
#  Reference value :  1.76509e-05
#  Reference value :  1.79729e-05
#  Reference value :  1.84190e-05
#  Reference value :  1.89609e-05
#  Reference value :  1.94712e-05
#  Reference value :  1.98854e-05
#  Reference value :  2.03129e-05
#  Reference value :  2.08842e-05
#  Reference value :  2.14270e-05
#  Reference value :  2.16609e-05
#  Reference value :  2.18204e-05
#  Reference value :  2.20834e-05
#  Reference value :  2.23087e-05
#  Reference value :  2.25951e-05
#  Reference value :  2.28942e-05
#  Reference value :  2.32209e-05
#  Reference value :  2.34009e-05
#  Reference value :  2.35779e-05
#  Reference value :  2.40384e-05
#  Reference value :  2.46195e-05
#  Reference value :  2.51829e-05
#  Reference value :  2.56007e-05
#  Reference value :  2.58512e-05
#  Reference value :  2.61451e-05
#  Reference value :  2.66545e-05
#  Reference value :  2.71695e-05
#  Reference value :  2.77643e-05
#  Reference value :  2.82184e-05
#  Reference value :  2.88031e-05
#  Reference value :  2.94185e-05
#  Reference value :  3.00072e-05
#  Reference value :  3.06059e-05
#  Reference value :  3.11994e-05
#  Reference value :  3.17602e-05
#  Reference value :  3.23195e-05
#  Reference value :  3.29471e-05
#  Reference value :  3.34887e-05
#  Reference value :  3.40371e-05
#  Reference value :  3.46187e-05
#  Reference value :  3.53037e-05
#  Reference value :  3.58954e-05
#  Reference value :  3.64621e-05
#  Reference value :  3.68879e-05
#  Reference value :  3.72687e-05
#  Reference value :  3.76047e-05
#  Reference value :  3.78187e-05
#  Reference value :  3.81246e-05
#  Reference value :  3.81937e-05
#  Reference value :  3.85796e-05
#  Reference value :  3.89812e-05
#  Reference value :  3.93046e-05
#  Reference value :  3.96587e-05
#  Reference value :  4.01821e-05
#  Reference value :  4.07087e-05
#  Reference value :  4.12191e-05
#  Reference value :  4.17620e-05
#  Reference value :  4.23646e-05
#  Reference value :  4.29395e-05
#  Reference value :  4.35079e-05
#  Reference value :  4.41120e-05
#  Reference value :  4.46910e-05
#  Reference value :  4.52920e-05
#  Reference value :  4.59210e-05
#  Reference value :  4.64687e-05
#  Reference value :  4.70593e-05
#  Reference value :  4.76537e-05
#  Reference value :  4.82943e-05
#  Reference value :  4.89620e-05
#  Reference value :  4.95676e-05
#  Reference value :  5.01537e-05
#  Reference value :  5.08010e-05
#  Reference value :  5.13993e-05
#  Reference value :  5.20579e-05
#  Reference value :  5.26834e-05
#  Reference value :  5.32862e-05
#  Reference value :  5.39192e-05
#  Reference value :  5.45104e-05
#  Reference value :  5.51875e-05
#  Reference value :  5.57645e-05
#  Reference value :  5.62550e-05
#  Reference value :  5.67142e-05
#  Reference value :  5.71351e-05
#  Reference value :  5.77720e-05
#  Reference value :  5.83559e-05
#  Reference value :  5.90028e-05
#  Reference value :  5.96412e-05
#  Reference value :  6.02210e-05
#  Reference value :  6.08829e-05
#  Reference value :  6.15168e-05
#  Reference value :  6.21637e-05
#  Reference value :  6.28011e-05
#  Reference value :  6.34013e-05
#  Reference value :  6.40720e-05
#  Reference value :  6.46593e-05
#  Reference value :  6.52662e-05
#  Reference value :  6.58835e-05
#  Reference value :  6.65204e-05
#  Reference value :  6.71796e-05
#  Reference value :  6.77895e-05
#  Reference value :  6.84637e-05
#  Reference value :  6.90921e-05
#  Reference value :  6.97404e-05
#  Reference value :  7.03921e-05
#  Reference value :  7.10024e-05
#  Reference value :  7.16321e-05
#  Reference value :  7.22796e-05
#  Reference value :  7.28987e-05
#  Reference value :  7.34787e-05
#  Reference value :  7.39504e-05
#  Reference value :  7.44779e-05
#  Reference value :  7.48812e-05
#  Reference value :  7.51704e-05
#  Reference value :  7.53446e-05
#  Reference value :  7.56184e-05
#  Reference value :  7.57962e-05
#  Reference value :  7.61904e-05
#  Reference value :  7.65521e-05
#  Reference value :  7.68321e-05
#  Reference value :  7.72546e-05
#  Reference value :  7.78570e-05
#  Reference value :  7.84059e-05
#  Reference value :  7.89001e-05
#  Reference value :  7.92918e-05
#  Reference value :  7.97501e-05
#  Reference value :  8.01860e-05
#  Reference value :  8.06870e-05
#  Reference value :  8.10979e-05
#  Reference value :  8.16024e-05
#  Reference value :  8.22262e-05
#  Reference value :  8.28701e-05
#  Reference value :  8.32293e-05
#  Reference value :  8.36031e-05
#  Reference value :  8.38937e-05
#  Reference value :  8.43695e-05
#  Reference value :  8.49051e-05
#  Reference value :  8.54620e-05
#  Reference value :  8.60184e-05
#  Reference value :  8.66007e-05
#  Reference value :  8.72018e-05
#  Reference value :  8.77017e-05
#  Reference value :  8.83887e-05
#  Reference value :  8.89634e-05
#  Reference value :  8.95454e-05
#  Reference value :  9.01234e-05
#  Reference value :  9.07445e-05
#  Reference value :  9.13626e-05
#  Reference value :  9.18895e-05
#  Reference value :  9.22404e-05
#  Reference value :  9.26169e-05
#  Reference value :  9.29785e-05
#  Reference value :  9.35395e-05
#  Reference value :  9.41385e-05
#  Reference value :  9.46487e-05
#  Reference value :  9.51912e-05
#  Reference value :  9.55737e-05
#  Reference value :  9.60393e-05
#  Reference value :  9.66023e-05
#  Reference value :  9.72144e-05
#  Reference value :  9.77885e-05
#  Reference value :  9.83062e-05
#  Reference value :  9.87745e-05
#  Reference value :  9.92643e-05
#  Reference value :  9.96685e-05
#  Reference value :  1.00230e-04
#  Reference value :  1.00618e-04
#  Reference value :  1.00819e-04
#  Reference value :  1.01018e-04
#  Reference value :  1.01418e-04
#  Reference value :  1.01996e-04
#  Reference value :  1.02590e-04
#  Reference value :  1.03004e-04
#  Reference value :  1.03356e-04
#  Reference value :  1.03837e-04
#  Reference value :  1.04404e-04
#  Reference value :  1.04969e-04
#  Reference value :  1.05494e-04
#  Reference value :  1.06094e-04
#  Reference value :  1.06690e-04
#  Reference value :  1.07225e-04
#  Reference value :  1.07792e-04
#  Reference value :  1.08341e-04
#  Reference value :  1.08921e-04
#  Reference value :  1.09219e-04
#  Reference value :  1.09738e-04
#  Reference value :  1.10243e-04
#  Reference value :  1.10703e-04
#  Reference value :  1.11018e-04
#  Reference value :  1.11342e-04
#  Reference value :  1.11818e-04
#  Reference value :  1.12375e-04
#  Reference value :  1.12952e-04
#  Reference value :  1.13553e-04
#  Reference value :  1.14140e-04
#  Reference value :  1.14631e-04
#  Reference value :  1.15142e-04
#  Reference value :  1.15640e-04
#  Reference value :  1.16118e-04
#  Reference value :  1.16431e-04
#  Reference value :  1.16931e-04
#  Reference value :  1.17526e-04
#  Reference value :  1.18110e-04
#  Reference value :  1.18717e-04
#  Reference value :  1.19236e-04
#  Reference value :  1.19801e-04
#  Reference value :  1.20307e-04
#  Reference value :  1.20818e-04
#  Reference value :  1.21403e-04
#  Reference value :  1.22035e-04
#  Reference value :  1.22601e-04
#  Reference value :  1.23178e-04
#  Reference value :  1.23811e-04
#  Reference value :  1.24395e-04
#  Reference value :  1.24910e-04
#  Reference value :  1.25488e-04
#  Reference value :  1.26080e-04
#  Reference value :  1.26628e-04
#  Reference value :  1.27020e-04
#  Reference value :  1.27581e-04
#  Reference value :  1.28082e-04
#  Reference value :  1.28619e-04
#  Reference value :  1.29069e-04
#  Reference value :  1.29525e-04
#  Reference value :  1.30019e-04
#  Reference value :  1.30530e-04
#  Reference value :  1.31048e-04
#  Reference value :  1.31596e-04
#  Reference value :  1.32112e-04
#  Reference value :  1.32611e-04
#  Reference value :  1.33068e-04
#  Reference value :  1.33485e-04
#  Reference value :  1.33947e-04
#  Reference value :  1.34381e-04
#  Reference value :  1.34865e-04
#  Reference value :  1.35429e-04
#  Reference value :  1.35955e-04
#  Reference value :  1.36529e-04
#  Reference value :  1.37106e-04
#  Reference value :  1.37618e-04
#  Reference value :  1.38206e-04
#  Reference value :  1.38776e-04
#  Reference value :  1.39343e-04
#  Reference value :  1.39910e-04
#  Reference value :  1.40437e-04
#  Reference value :  1.41001e-04
#  Reference value :  1.41457e-04
#  Reference value :  1.41995e-04
#  Reference value :  1.42155e-04
#  Reference value :  1.42540e-04
#  Reference value :  1.42878e-04
#  Reference value :  1.43212e-04
#  Reference value :  1.43630e-04
#  Reference value :  1.44218e-04
#  Reference value :  1.44691e-04
#  Reference value :  1.45232e-04
#  Reference value :  1.45848e-04
#  Reference value :  1.46453e-04
#  Reference value :  1.47070e-04
#  Reference value :  1.47652e-04
#  Reference value :  1.48018e-04
#  Reference value :  1.48404e-04
#  Reference value :  1.48571e-04
#  Reference value :  1.48874e-04
#  Reference value :  1.49348e-04
#  Reference value :  1.49893e-04
#  Reference value :  1.50453e-04
#  Reference value :  1.51082e-04
#  Reference value :  1.51713e-04
#  Reference value :  1.52373e-04
#  Reference value :  1.52969e-04
#  Reference value :  1.53449e-04
#  Reference value :  1.53987e-04
#  Reference value :  1.54544e-04
#  Reference value :  1.55120e-04
#  Reference value :  1.55733e-04
#  Reference value :  1.56335e-04
#  Reference value :  1.56971e-04
#  Reference value :  1.57608e-04
#  Reference value :  1.58251e-04
#  Reference value :  1.58825e-04
#  Reference value :  1.59442e-04
#  Reference value :  1.59940e-04
#  Reference value :  1.60401e-04
#  Reference value :  1.60801e-04
#  Reference value :  1.61288e-04
#  Reference value :  1.61925e-04
#  Reference value :  1.62501e-04
#  Reference value :  1.63011e-04
#  Reference value :  1.63575e-04
#  Reference value :  1.64118e-04
#  Reference value :  1.64645e-04
#  Reference value :  1.65002e-04
#  Reference value :  1.65435e-04
#  Reference value :  1.65968e-04
#  Reference value :  1.66463e-04
#  Reference value :  1.67001e-04
#  Reference value :  1.67653e-04
#  Reference value :  1.68252e-04
#  Reference value :  1.68892e-04
#  Reference value :  1.69510e-04
#  Reference value :  1.70130e-04
#  Reference value :  1.70730e-04
#  Reference value :  1.71125e-04
#  Reference value :  1.71455e-04
#  Reference value :  1.71985e-04
#  Reference value :  1.72545e-04
#  Reference value :  1.73029e-04
#  Reference value :  1.73418e-04
#  Reference value :  1.73810e-04
#  Reference value :  1.74125e-04
#  Reference value :  1.74713e-04
#  Reference value :  1.75323e-04
#  Reference value :  1.75828e-04
#  Reference value :  1.76382e-04
#  Reference value :  1.76745e-04
#  Reference value :  1.77127e-04
#  Reference value :  1.77633e-04
#  Reference value :  1.78186e-04
#  Reference value :  1.78469e-04
#  Reference value :  1.78965e-04
#  Reference value :  1.79582e-04
#  Reference value :  1.80019e-04
#  Reference value :  1.80219e-04
#  Reference value :  1.80458e-04
#  Reference value :  1.80704e-04
#  Reference value :  1.81245e-04
#  Reference value :  1.81870e-04
#  Reference value :  1.82371e-04
#  Reference value :  1.82778e-04
#  Reference value :  1.83141e-04
#  Reference value :  1.83723e-04
#  Reference value :  1.84282e-04
#  Reference value :  1.84827e-04
#  Reference value :  1.85454e-04
#  Reference value :  1.85705e-04
#  Reference value :  1.85707e-04
#  Reference value :  1.85799e-04
#  Reference value :  1.85882e-04
#  Reference value :  1.86269e-04
#  Reference value :  1.86599e-04
#  Reference value :  1.86955e-04
#  Reference value :  1.87275e-04
#  Reference value :  1.87603e-04
#  Reference value :  1.88084e-04
#  Reference value :  1.88455e-04
#  Reference value :  1.89018e-04
#  Reference value :  1.89604e-04
#  Reference value :  1.90216e-04
#  Reference value :  1.90801e-04
#  Reference value :  1.91355e-04
#  Reference value :  1.91850e-04
#  Reference value :  1.92313e-04
#  Reference value :  1.92537e-04
#  Reference value :  1.92725e-04
#  Reference value :  1.93040e-04
#  Reference value :  1.93471e-04
#  Reference value :  1.94004e-04
#  Reference value :  1.94412e-04
#  Reference value :  1.94911e-04
#  Reference value :  1.95405e-04
#  Reference value :  1.95875e-04
#  Reference value :  1.96382e-04
#  Reference value :  1.96820e-04
#  Reference value :  1.97285e-04
#  Reference value :  1.97696e-04
#  Reference value :  1.98126e-04
#  Reference value :  1.98723e-04
#  Reference value :  1.99317e-04
#  Reference value :  1.99902e-04
#  Reference value :  2.00530e-04
#  Reference value :  2.01005e-04
#  Reference value :  2.01596e-04
#  Reference value :  2.02176e-04
#  Reference value :  2.02713e-04
#  Reference value :  2.03271e-04
#  Reference value :  2.03801e-04
#  Reference value :  2.04265e-04
#  Reference value :  2.04801e-04
#  Reference value :  2.05371e-04
# No. of Data Rows : 275033
# Note: Simulation executed from .control section

# %% [markdown]
# ## Waveform import
#
# The transient data exported by NGspice is imported into a Pandas DataFrame with descriptive column names. Since `wrdata` generates one time column per waveform, duplicated time vectors are verified for consistency and merged into a single `time` column for subsequent analysis.

# %%
data = pd.read_csv(
    WORK_DIR / "tb_bootstrapped.csv",
    sep=r"\s+",
    header=None,
    names=[
        "t_vin", "vin",
        "t_vout", "vout",
        "t_clk", "clk"
    ]
)

# Verify that all time columns are equivalent
time_match = (
    np.allclose(data["t_vin"], data["t_vout"]) and
    np.allclose(data["t_vin"], data["t_clk"])
)

if time_match:
    data = (
        data.rename(columns={"t_vin": "time"})
            [["time", "vin", "vout", "clk"]]
    )
else:
    raise ValueError("Time columns are not identical.")

print(data.head())
# Out:
#            time       vin      vout       clk
# 0  0.000000e+00  1.650000  0.087461  0.000000
# 1  8.333330e-10  1.671471  0.090171  2.749999
# 2  1.666666e-09  1.692939  1.475153  3.300000
# 3  2.499999e-09  1.714399  1.703897  3.300000
# 4  3.333332e-09  1.735849  1.729896  3.300000

# %% [markdown]
# ## Plot Waveforms
#
# To simplify visualization, only the first input signal period is displayed. The period is computed automatically from the simulation parameters, and the resulting plots show the input voltage, sampled output voltage, and sampling clock on a common time axis.

# %%
# Compute the input frequency and period
Fin = Nc / Ns * Fs
Tin = 1 / Fin

# Keep only the first input period
data_plot = data[data["time"] <= Tin]

# Create the figure
fig, (ax1, ax2) = plt.subplots(
    2, 1,
    figsize=(4, 3.5),
    sharex=True,
    constrained_layout=True,
)

# Plot the input and output voltages
ax1.plot(data_plot["time"], data_plot["vin"], label=r"$V_{in}$", color="tab:blue")
ax1.plot(data_plot["time"], data_plot["vout"], label=r"$V_{out}$", color="tab:red")

ax1.set_ylabel("Voltage (V)")
ax1.grid(True, linestyle=":", linewidth=0.6)
ax1.legend(loc="upper right")

# Plot the sampling clock
ax2.plot(data_plot["time"], data_plot["clk"], label="Samp CLK", color="goldenrod")

ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Voltage (V)")
ax2.grid(True, linestyle=":", linewidth=0.6)
ax2.legend(loc="upper right")

# Display the time axis using engineering notation
ax2.xaxis.set_major_formatter(EngFormatter(unit="s"))

plt.show()

# %% [markdown]
# ## Output FFT
#
# The output waveform is sampled at the same instants as the switched-capacitor circuit, starting after the initial discarded cycles to avoid switching transients. The sampled sequence is then processed using a normalized FFT to obtain the one-sided power spectrum for performance analysis.

# %%
# Sampling parameters
Ts = 1 / Fs
Ton = Ts / 12

# First sampling instant after the discarded cycles
t0 = Nspare * Ts + 2 * Ton

# Generate the sampling instants
sample_times = t0 + np.arange(Ns) * Ts

# Interpolate the transient waveform at the sampling instants
vout_samples = np.interp(
    sample_times,
    data["time"],
    data["vout"],
)

# Compute the normalized FFT
fft = np.fft.fft(vout_samples, n=Ns)
fft /= Ns

# Keep the one-sided spectrum
fft = fft[: Ns // 2 + 1]
fft[1:-1] *= 2

# Frequency axis
f = np.fft.rfftfreq(Ns, d=Ts)

# Power spectrum
PSD = np.abs(fft) ** 2

# Power spectrum in dB
PSD_db = 10 * np.log10(np.maximum(PSD, 1e-20))

# %% [markdown]
# The one-sided FFT computed in the previous section is displayed as a function of frequency. This spectrum provides a convenient representation of the sampled output and serves as the basis for evaluating the S&H performance.

# %%
# Create the figure
fig, ax = plt.subplots(figsize=(5, 3.2))

# Plot the one-sided spectrum
ax.plot(
    f[1:],
    PSD_db[1:],
    color="tab:blue",
    linewidth=1,
)

# Use engineering notation for the frequency axis
ax.xaxis.set_major_formatter(EngFormatter(unit="Hz"))

ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Magnitude (dB)")

# Configure the grid
ax.grid(
    True,
    which="both",
    linestyle=":",
    linewidth=0.6,
)

plt.show()

# %% [markdown]
# ## Compute SNDR and ENOB
#
# The sampled spectrum is used to estimate the Signal-to-Noise-and-Distortion Ratio (SNDR) and the Effective Number of Bits (ENOB). The computation excludes the DC component and treats the fundamental tone as the signal, while the remaining spectral power is considered noise and distortion.

# %%
def compute_enob(PSD, f, fin, fs, Nfft, bandwidth=None):
    """
    Compute SNDR and ENOB over the selected frequency region.

    If bandwidth is None, the full spectrum is used.
    Otherwise, only frequencies below the specified bandwidth
    are included in the calculation.
    """

    df = fs / Nfft

    # Select the frequency region
    if bandwidth is None:
        region_mask = np.ones_like(f, dtype=bool)
    else:
        region_mask = np.abs(f) < bandwidth

    # Identify the fundamental tone and DC component
    fundamental_mask = np.abs(f - fin) < df / 2
    dc_mask = (f == 0)

    fundamental_mask &= region_mask
    dc_mask &= region_mask

    # Compute the signal, noise, and distortion powers
    total_power = np.sum(PSD[region_mask])
    fundamental_power = np.sum(PSD[fundamental_mask])
    dc_power = np.sum(PSD[dc_mask])

    noise_dist_power = total_power - fundamental_power - dc_power

    # Compute SNDR and ENOB
    sndr = 10 * np.log10(fundamental_power / noise_dist_power)
    enob = (sndr - 1.7609) / 6.0206

    return sndr, enob


# Compute SNDR and ENOB over the full Nyquist band
sndr_full, enob_full = compute_enob(
    PSD,
    f,
    Fin,
    Fs,
    Ns,
)

# Display the results
print("============== RESULTS ==============")
print(f"SNDR : {sndr_full:.4f} dB")
print(f"ENOB : {enob_full:.4f} bits")
# Out:
# ============== RESULTS ==============
# SNDR : 64.0259 dB
# ENOB : 10.3420 bits
